# %%
pip install yfinance --timeout 100
# Out:
# ...
#   Using cached yfinance-0.2.37-py2.py3-none-any.whl (72 kB)
# ...
#   Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Using cached frozendict-2.4.1-cp39-cp39-win_amd64.whl (36 kB)
# ...
#   Using cached lxml-5.2.1-cp39-cp39-win_amd64.whl (3.8 MB)
# ...
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# ...
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# ...
#   Created wheel for peewee: filename=peewee-3.17.1-py3-none-any.whl size=136948 sha256=ba8da5fbafdd425e86089a15c025a7aa4746fe7a27047231207d86ef478cbf38
# ...

# %%
pip list
# Out:
# Package                            VersionNote: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -yping-extensions (c:\users\yasmina\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\yasmina\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (c:\users\yasmina\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\yasmina\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (c:\users\yasmina\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\yasmina\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (c:\users\yasmina\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\yasmina\anaconda3\lib\site-packages)
# ---------------------------------- --------------------
# ...

# %%
import yfinance as yf
import os
import pandas as pd

# %%
btc_ticker = yf.Ticker("BTC-USD")

# %%
current_price = btc_ticker.info['previousClose']
print(f"the previous day's closing price ${current_price}")
# Out:
# the previous day's closing price $70032.84

# %%
try:
  prix_actuel = btc_ticker.info['regularMarketPrice']
  print(f"Prix actuel du Bitcoin : ${prix_actuel}")
except KeyError:
  # Gérer le cas où 'regularMarketPrice' n'est pas disponible
  print("Prix du marché régulier indisponible")
# Out:
# Prix du marché régulier indisponible

# %%
btc = pd.read_csv("btc.csv",index_col=0) #la premiére colonne date est definie comme index

# %%
btc
# Out:
#                                    Open          High           Low  \
# Date
# 2014-09-17 00:00:00+00:00    465.864014    468.174011    452.421997
# 2014-09-18 00:00:00+00:00    456.859985    456.859985    413.104004
# 2014-09-19 00:00:00+00:00    424.102997    427.834991    384.532013
# 2014-09-20 00:00:00+00:00    394.673004    423.295990    389.882996
# 2014-09-21 00:00:00+00:00    408.084991    412.425995    393.181000
# ...                                 ...           ...           ...
# 2024-04-08 00:00:00+00:00  69362.554688  72715.359375  69064.242188
# 2024-04-09 00:00:00+00:00  71632.500000  71742.507812  68212.921875
# 2024-04-10 00:00:00+00:00  69140.242188  71093.429688  67503.562500
# 2024-04-11 00:00:00+00:00  70575.734375  71256.234375  69571.812500
# 2024-04-12 00:00:00+00:00  70032.843750  71195.929688  66052.554688
#
#                                   Close       Volume  Dividends  Stock Splits
# Date
# ...

# %%
#convertir l'index en objet de type datetime
btc.index = pd.to_datetime(btc.index)

# %%
del btc["Dividends"]
del btc["Stock Splits"]

# %%
btc.head(5)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2014-09-17 00:00:00+00:00  465.864014  468.174011  452.421997  457.334015
# 2014-09-18 00:00:00+00:00  456.859985  456.859985  413.104004  424.440002
# 2014-09-19 00:00:00+00:00  424.102997  427.834991  384.532013  394.795990
# 2014-09-20 00:00:00+00:00  394.673004  423.295990  389.882996  408.903992
# 2014-09-21 00:00:00+00:00  408.084991  412.425995  393.181000  398.821014
#
#                              Volume
# Date
# 2014-09-17 00:00:00+00:00  21056800
# 2014-09-18 00:00:00+00:00  34483200
# 2014-09-19 00:00:00+00:00  37919700
# 2014-09-20 00:00:00+00:00  36863600
# 2014-09-21 00:00:00+00:00  26580100

# %%
btc.dtypes
# Out:
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume      int64
# dtype: object

# %%
#Rendre tous les noms de colonnes en miniscule
btc.columns = [c.lower() for c in btc.columns]

# %%
btc.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'volume'], dtype='object')

# %%
#La variation du coût de la clôture au fil des années.
btc.plot.line(y="close", use_index=True)# use_index=True:definir la colonne d'index (date) comme axe x
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
btc.plot.line(y="open", use_index=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
btc.plot.line(y="volume", use_index=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
wiki = pd.read_csv("wikipedia_edits.csv", index_col=0, parse_dates=True)

# %%
#Les discussions et les commentaires autour des articles Wikipédia sur le Bitcoin peuvent être analysés pour extraire des informations sur le sentiment des utilisateurs envers la cryptomonnaie
wiki
# Out:
#             edit_count  sentiment  neg_sentiment
# 2009-04-06    0.133333  -0.018351       0.025000
# 2009-04-07    0.000000   0.000000       0.000000
# 2009-04-08    0.000000   0.000000       0.000000
# 2009-04-09    0.000000   0.000000       0.000000
# 2009-04-10    0.000000   0.000000       0.000000
# ...                ...        ...            ...
# 2022-09-04    0.400000  -0.108480       0.150000
# 2022-09-05    0.400000  -0.108480       0.150000
# 2022-09-06    0.433333  -0.081502       0.150000
# 2022-09-07    0.433333  -0.081502       0.150000
# 2022-09-08    0.466667  -0.114104       0.183333
#
# [4904 rows x 3 columns]

# %%
btc = btc.merge(wiki, left_index=True, right_index=True)

# %%
btc
# Out:
#                                    open          high           low  \
# Date
# 2014-09-17 00:00:00+00:00    465.864014    468.174011    452.421997
# 2014-09-18 00:00:00+00:00    456.859985    456.859985    413.104004
# 2014-09-19 00:00:00+00:00    424.102997    427.834991    384.532013
# 2014-09-20 00:00:00+00:00    394.673004    423.295990    389.882996
# 2014-09-21 00:00:00+00:00    408.084991    412.425995    393.181000
# ...                                 ...           ...           ...
# 2024-04-08 00:00:00+00:00  69362.554688  72715.359375  69064.242188
# 2024-04-09 00:00:00+00:00  71632.500000  71742.507812  68212.921875
# 2024-04-10 00:00:00+00:00  69140.242188  71093.429688  67503.562500
# 2024-04-11 00:00:00+00:00  70575.734375  71256.234375  69571.812500
# 2024-04-12 00:00:00+00:00  70032.843750  71195.929688  66052.554688
#
#                                   close       volume
# Date
# 2014-09-17 00:00:00+00:00    457.334015     21056800
# ...

# %%
btc["tomorrow"] = btc["close"].shift(-1)

# %%
btc["target"] = (btc["tomorrow"] > btc["close"]).astype(int)

# %%
btc["target"].value_counts()
# Out:
# 1    1563
# 0    1351
# Name: target, dtype: int64

# %%
btc
# Out:
#                     open          high           low         close  \
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2022-09-04  19832.470703  19999.689453  19636.816406  19986.712891
# 2022-09-05  19988.789062  20031.160156  19673.046875  19812.371094
# 2022-09-06  19817.724609  20155.269531  18800.171875  18837.667969
# 2022-09-07  18837.683594  19427.171875  18644.466797  19290.324219
# 2022-09-08  19309.482422  19410.619141  19089.548828  19337.371094
#
#                  volume  edit_count  sentiment  neg_sentiment      tomorrow  \
# 2014-09-17     21056800    5.033333  -0.232191       0.532718    424.440002
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=50, random_state=1)

train = btc.iloc[:-200]
test = btc.iloc[-200:]

predictors = ["close", "volume", "open", "high", "low", "edit_count", "sentiment", "neg_sentiment"]
model.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=50, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])
preds = pd.Series(preds, index=test.index)
precision_score(test["target"], preds)
# Out:
# 0.48484848484848486

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="predictions")
    combined = pd.concat([test["target"], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=1095, step=150):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    
    return pd.concat(all_predictions)

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -yping-extensions (c:\users\yasmina\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\yasmina\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (c:\users\yasmina\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\yasmina\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (c:\users\yasmina\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\yasmina\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (c:\users\yasmina\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\yasmina\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (c:\users\yasmina\anaconda3\lib\site-packages)
# ...

# %%
from xgboost import XGBClassifier

model = XGBClassifier(random_state=1, learning_rate=.1, n_estimators=200)
predictions = backtest(btc, model, predictors)

# %%
predictions["predictions"].value_counts()
# Out:
# 1    1052
# 0     767
# Name: predictions, dtype: int64

# %%
precision_score(predictions["target"], predictions["predictions"])
# Out:
# 0.5171102661596958

# %%
def compute_rolling(btc):
    horizons = [2,7,60,365]
    new_predictors = ["close", "sentiment", "neg_sentiment"]

    for horizon in horizons:
        rolling_averages = btc.rolling(horizon, min_periods=1).mean()

        ratio_column = f"close_ratio_{horizon}"
        btc[ratio_column] = btc["close"] / rolling_averages["close"]
        
        edit_column = f"edit_{horizon}"
        btc[edit_column] = rolling_averages["edit_count"]

        rolling = btc.rolling(horizon, closed='left', min_periods=1).mean()
        trend_column = f"trend_{horizon}"
        btc[trend_column] = rolling["target"]

        new_predictors+= [ratio_column, trend_column, edit_column]
    return btc, new_predictors

# %%
btc, new_predictors = compute_rolling(btc.copy())

# %%
predictions = backtest(btc, model, new_predictors)

# %%
precision_score(predictions["target"], predictions["predictions"])
# Out:
# 0.5240328253223916

# %%
#target = 0 indique une prédiction de baisse du prix
#target = 1 indique une prédiction de hausse du prix
predictions
# Out:
#             target  predictions
# 2017-09-16       0            0
# 2017-09-17       1            1
# 2017-09-18       0            0
# 2017-09-19       0            1
# 2017-09-20       0            1
# ...            ...          ...
# 2022-09-04       0            1
# 2022-09-05       0            1
# 2022-09-06       1            1
# 2022-09-07       1            1
# 2022-09-08       0            1
#
# [1819 rows x 2 columns]

# %%
btc2024 = btc_ticker.history(period="max")
btc2024.to_csv("btc.csv")

# %%
btc2024
# Out:
#                                    Open          High           Low  \
# Date
# 2014-09-17 00:00:00+00:00    465.864014    468.174011    452.421997
# 2014-09-18 00:00:00+00:00    456.859985    456.859985    413.104004
# 2014-09-19 00:00:00+00:00    424.102997    427.834991    384.532013
# 2014-09-20 00:00:00+00:00    394.673004    423.295990    389.882996
# 2014-09-21 00:00:00+00:00    408.084991    412.425995    393.181000
# ...                                 ...           ...           ...
# 2024-04-08 00:00:00+00:00  69362.554688  72715.359375  69064.242188
# 2024-04-09 00:00:00+00:00  71632.500000  71742.507812  68212.921875
# 2024-04-10 00:00:00+00:00  69140.242188  71093.429688  67503.562500
# 2024-04-11 00:00:00+00:00  70575.734375  71256.234375  69571.812500
# 2024-04-12 00:00:00+00:00  70032.843750  71195.929688  66052.554688
#
#                                   Close       Volume  Dividends  Stock Splits
# Date
# ...

# %%
btc2024.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
del btc2024['Dividends']
del btc2024['Stock Splits']

# %%
btc2024.head(5)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2014-09-17 00:00:00+00:00  465.864014  468.174011  452.421997  457.334015
# 2014-09-18 00:00:00+00:00  456.859985  456.859985  413.104004  424.440002
# 2014-09-19 00:00:00+00:00  424.102997  427.834991  384.532013  394.795990
# 2014-09-20 00:00:00+00:00  394.673004  423.295990  389.882996  408.903992
# 2014-09-21 00:00:00+00:00  408.084991  412.425995  393.181000  398.821014
#
#                              Volume
# Date
# 2014-09-17 00:00:00+00:00  21056800
# 2014-09-18 00:00:00+00:00  34483200
# 2014-09-19 00:00:00+00:00  37919700
# 2014-09-20 00:00:00+00:00  36863600
# 2014-09-21 00:00:00+00:00  26580100

# %%
btc2024.shape
# Out:
# (3496, 5)

# %%
import pandas as pd

# Créer une Series
s = pd.Series([1, 2, 3, 4, 5])

# Créer un DataFrame à partir d'un dictionnaire
data = {'Nom': ['Alice', 'Bob', 'Charlie', 'David'],
        'Âge': [25, 30, 35, 40]}
df = pd.DataFrame(data)

print(s)
print(df)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
#        Nom  Âge
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40
